# %%
#import package
import torch
import torchvision
import matplotlib.pyplot as plt
import numpy as np
from torchvision import transforms
from torch.utils.data import DataLoader
import os
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
## Create transform wait out normalize
manual_transform = transforms.Compose([
    transforms.Resize((32,32)),
    transforms.ToTensor()
    ])

# %%
## Downloading data
BATCH_SIZE=32
NUM_WORKER=os.cpu_count()
train_set = torchvision.datasets.CIFAR10(root = 'data',train=True,download=True,transform=manual_transform)
test_set = torchvision.datasets.CIFAR10(root = 'data',train=False,download=True,transform=manual_transform)

# %%
# %%writefile find_normalize_number.py
import torchvision
import torch
import os
def find_normalize_number(trainset:torchvision.datasets,
                          num_workers:int = os.cpu_count()):
    loader = torch.utils.data.DataLoader(trainset, batch_size=200, shuffle=False, num_workers=2)

    mean = 0.
    std = 0.
    nb_samples = 0.

    for data, _ in loader:
        batch_samples = data.size(0)
        data = data.view(batch_samples, data.size(1), -1)  # flatten H*W
        mean += data.mean(2).sum(0)
        std += data.std(2).sum(0)
        nb_samples += batch_samples

    mean /= nb_samples
    std /= nb_samples
    return mean,std
# Out:
# Overwriting find_normalize_number.py

# %%
import find_normalize_number
mean,std=find_normalize_number.find_normalize_number(train_set)

# %%
mean,std
# Out:
# (tensor([0.4914, 0.4822, 0.4465]), tensor([0.2023, 0.1994, 0.2010]))

# %%
## Create transform wait normalize number
manual_transform = transforms.Compose([
    transforms.Resize((128,128)),
    transforms.ToTensor(),
    transforms.Normalize(mean,std)
    ])

# %%
## Downloading data
BATCH_SIZE=32
NUM_WORKER=os.cpu_count()
train_set = torchvision.datasets.CIFAR10(root = 'data',train=True,download=False,transform=manual_transform)
test_set = torchvision.datasets.CIFAR10(root = 'data',train=False,download=False,transform=manual_transform)

# %%
train_dataloader = DataLoader(dataset=train_set,batch_size=BATCH_SIZE,shuffle=True,num_workers=NUM_WORKER)
test_dataloader = DataLoader(dataset=test_set,batch_size=BATCH_SIZE,shuffle=False,num_workers=NUM_WORKER)
class_names = train_dataloader.dataset.classes

# %%
train_dataloader.dataset
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                Resize(size=(128, 128), interpolation=bilinear, max_size=None, antialias=True)
#                ToTensor()
#                Normalize(mean=tensor([0.4914, 0.4822, 0.4465]), std=tensor([0.2023, 0.1994, 0.2010]))
#            )

# %%
images , label = next(iter(train_dataloader))

# %%
#plot some image
img = images[5]
img = img * std[:, None, None] + mean[:, None, None]  # reverse normalization
plt.imshow(img.permute(1, 2, 0))
plt.show()
class_names[label[5]]
# Out:
# 'automobile'

# %%
# Ok lets create our CNN model to train

# %%
from torch import nn
class CIFAR10Model(nn.Module):
    def __init__(self,hidden_unit,input_shape,output_shape):
        super().__init__()
        self.conv_block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,out_channels=hidden_unit,kernel_size=3,stride=1,padding=0),
            nn.ReLU(),
            nn.Conv2d(in_channels=hidden_unit,out_channels=hidden_unit,kernel_size=3,stride=1,padding=0),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,stride=2)#default stride size is same as kernelsize
        )
        self.conv_block_2=nn.Sequential(
            nn.Conv2d(in_channels=hidden_unit,out_channels=hidden_unit,kernel_size=3,stride=1,padding=0),
            nn.ReLU(),
            nn.Conv2d(in_channels=hidden_unit,out_channels=hidden_unit,kernel_size=3,stride=1,padding=0),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,stride=2)#default stride size is same as kernelsize
        )
        self.classifier=nn.Sequential(
            nn.Flatten(),
            nn.Dropout(),
            nn.Linear(in_features=8410,
                      out_features=output_shape)
        )
    def forward(self,x):
        x = self.conv_block_1(x)
        x = self.conv_block_2(x)
        #print(f'shape is {x.shape}')
        x = self.classifier(x)
        return x
model = CIFAR10Model(hidden_unit=10,input_shape=3,output_shape=len(class_names)).to(device)

# %%
model(images.to(device))
# Out:
# tensor([[ 0.0055, -0.0145,  0.0558,  0.0213, -0.0478,  0.0382, -0.0458, -0.0253,
#          -0.0152, -0.0350],
#         [ 0.0345, -0.0252,  0.0192,  0.0216,  0.0136, -0.0108, -0.0154, -0.0183,
#          -0.0015, -0.0458],
#         [ 0.0734,  0.0070,  0.0225, -0.0168, -0.0316, -0.0204, -0.0430, -0.0439,
#           0.0098, -0.0323],
#         [ 0.0233,  0.0531, -0.0224,  0.0490,  0.0021,  0.0582, -0.0320,  0.0264,
#          -0.0437, -0.0157],
#         [ 0.0488,  0.0386, -0.0337,  0.0527,  0.0020,  0.0219, -0.0366,  0.0332,
#           0.0132, -0.0562],
#         [ 0.0544,  0.0202,  0.0240,  0.0291, -0.0317,  0.0192, -0.0147,  0.0060,
#          -0.0351, -0.0593],
#         [ 0.0437, -0.0179,  0.0033,  0.0518,  0.0017,  0.0588, -0.0531, -0.0101,
#          -0.0286, -0.0055],
#         [ 0.0160,  0.0261,  0.0164,  0.0363,  0.0061,  0.0064, -0.0242, -0.0140,
#          -0.0130, -0.0319],
#         [ 0.0206, -0.0087,  0.0132,  0.0444, -0.0473,  0.0209, -0.0364,  0.0180,
#          -0.0622, -0.0104],
#         [ 0.0710, -0.0110,  0.0172,  0.0090, -0.0172,  0.0511, -0.0280,  0.0168,
#          -0.0373, -0.0698],
#         [-0.0256,  0.0020, -0.0442, -0.0046,  0.0068, -0.0126, -0.0399,  0.0302,
#          -0.0504, -0.0228],
#         [ 0.0067,  0.0027, -0.0232,  0.0294, -0.0017,  0.0661, -0.0251, -0.0207,
#           0.0056, -0.0506],
#         [-0.0130,  0.0066, -0.0681,  0.0222, -0.0098,  0.0617, -0.0216,  0.0098,
#          -0.0627, -0.0497],
#         [ 0.0483,  0.0645, -0.0234, -0.0045,  0.0179,  0.0333, -0.0162, -0.0414,
#          -0.0046, -0.0412],
#         [ 0.0141, -0.0479, -0.0197,  0.0026, -0.0108,  0.0371, -0.0428,  0.0069,
#          -0.0687,  0.0234],
#         [-0.0019,  0.0111, -0.0429,  0.0059,  0.0046,  0.0356,  0.0112, -0.0107,
#          -0.0347, -0.0210],
#         [-0.0008,  0.0024,  0.0120,  0.0265,  0.0031, -0.0002, -0.0098, -0.0031,
#          -0.0560, -0.0149],
#         [ 0.0161,  0.0487, -0.0341,  0.0007, -0.0414,  0.0440, -0.0101, -0.0331,
#          -0.0305,  0.0069],
#         [-0.0216, -0.0176,  0.0057,  0.0362,  0.0097,  0.0306, -0.0397, -0.0151,
#           0.0106, -0.0198],
#         [ 0.0477, -0.0038,  0.0436,  0.0048,  0.0201,  0.0429, -0.0011,  0.0091,
#          -0.0114, -0.0344],
#         [ 0.0541, -0.0083, -0.0448,  0.0095,  0.0154,  0.0219, -0.0181,  0.0190,
#          -0.0614, -0.0170],
#         [-0.0068,  0.0578,  0.0118, -0.0094, -0.0364,  0.0171, -0.0330,  0.0276,
#          -0.0108, -0.0245],
#         [-0.0236,  0.0067,  0.0399,  0.0866,  0.0111,  0.0284, -0.0338, -0.0048,
#          -0.0490,  0.0239],
#         [ 0.0550,  0.0206,  0.0479,  0.0100,  0.0283,  0.0295, -0.0535, -0.0170,
#          -0.0164,  0.0197],
#         [ 0.0403,  0.0205,  0.0199,  0.0073, -0.0118,  0.0382, -0.0486,  0.0347,
#          -0.0543, -0.0548],
#         [ 0.0141, -0.0252, -0.0420,  0.0759,  0.0142,  0.0196, -0.0337, -0.0308,
#          -0.0417, -0.0685],
#         [ 0.0061,  0.0272,  0.0128,  0.0537, -0.0020,  0.0387,  0.0014, -0.0130,
#          -0.0259, -0.0656],
#         [ 0.0425,  0.0122,  0.0237, -0.0004,  0.0076,  0.0267, -0.0154,  0.0086,
#          -0.0557, -0.0444],
#         [-0.0043,  0.0266, -0.0157,  0.0430, -0.0007,  0.0514, -0.0475, -0.0503,
#          -0.0280, -0.0220],
#         [ 0.0373,  0.0164,  0.0116,  0.0444, -0.0093, -0.0113, -0.0012,  0.0197,
#          -0.0454, -0.0356],
#         [ 0.0229, -0.0144,  0.0328,  0.0414, -0.0580,  0.0652, -0.0597,  0.0294,
#          -0.0208,  0.0007],
#         [ 0.0386,  0.0328, -0.0108,  0.0703,  0.0441, -0.0041, -0.0152, -0.0136,
#          -0.0530, -0.0157]], grad_fn=<AddmmBackward0>)

# %%
##lets train our CIFAR10Model

# %%
optimizer = torch.optim.SGD(lr=0.01,params=model.parameters())
loss_fn = nn.CrossEntropyLoss()

# %%
def train_step(model:nn.Module,
          optimizer:torch.optim,
          loss_fn:nn.Module,
          dataloader:DataLoader,
          accuracy_fn,
          device:torch.device):
    model.train()
    train_acc,train_loss = 0,0
    for batch,(X,y) in enumerate(dataloader): ##--> Batch 0 || X shape: torch.Size([32, 3, 224, 224])  || y shape: torch.Size([32])
        print(f'batch_num:{batch}')
        X,y = X.to(device) , y.to(device)
        y_pred = model(X)
        loss = loss_fn(y_pred,y)
        train_acc+=accuracy_fn(y,y_pred.argmax(dim=1))
        train_loss+=loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    train_acc/=len(dataloader)
    train_loss/=len(dataloader)
    return train_loss,train_acc

# %%
def test_step(model:nn.Module,
             dataloader:DataLoader,
             loss_fn:nn.Module,
             accuracy_fn,
          device:torch.device):
    test_acc , test_loss = 0,0
    model.eval()
    with torch.inference_mode():
        for batch,(X,y) in enumerate(dataloader):
            X,y = X.to(device),y.to(device)
            y_pred = model(X)
            loss = loss_fn(y_pred,y)
            test_acc += accuracy_fn(y,y_pred.argmax(dim=1))
            test_loss += loss.item()

        test_loss/=len(dataloader)
        test_acc/=len(dataloader)
        return test_loss,test_acc

# %%
from tqdm.auto import tqdm
from timeit import default_timer as timer
def train(model:nn.Module,
         train_dataloader:DataLoader,
         test_dataloader:DataLoader,
         epochs:int,
         optimizer:torch.optim,
         loss_fn:nn.Module,
         accuracy_fn,
         device:torch.device):

    results={
        "train_loss":[],
        "train_acc":[],
        "test_loss":[],
        "test_acc":[]
    }
    start = timer()
    for epoch in tqdm(range(epochs)):
        train_loss,train_acc = train_step(model,optimizer,loss_fn,train_dataloader,accuracy_fn,device)
        test_loss,test_acc = test_step(model,test_dataloader,loss_fn,accuracy_fn,device)
        print(f"Epochs :{epoch} | Train loss :{train_loss:.4} | Train accuracy :{train_acc:.3} | Test loss :{test_loss:.4} | Test accuracy :{test_acc:.3} " )

        results["train_loss"].append(train_loss)
        results["train_acc"].append(train_acc)
        results["test_loss"].append(test_loss)
        results["test_acc"].append(test_acc)

    end = timer()
    print(f'Training & testing operation take {end-start} seconds!!')
    return results

# %%
def accuracy_fn(y_true, y_pred):
    """Calculates accuracy between target (y_true) and predictions (y_pred)."""
    correct = torch.eq(y_true, y_pred).sum().item()
    acc = (correct / len(y_pred)) * 100
    return acc

# %%
results = train(model,train_dataloader,test_dataloader,5,optimizer,loss_fn,accuracy_fn,device)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# batch_num:0
# batch_num:1
# batch_num:2
# batch_num:3
# batch_num:4
# batch_num:5
# batch_num:6
# batch_num:7
# batch_num:8
# batch_num:9
# batch_num:10
# batch_num:11
# batch_num:12
# batch_num:13
# batch_num:14
# batch_num:15
# batch_num:16
# batch_num:17
# batch_num:18
# batch_num:19
# batch_num:20
# batch_num:21
# batch_num:22
# batch_num:23
# batch_num:24
# batch_num:25
# batch_num:26
# batch_num:27
# batch_num:28
# batch_num:29
# batch_num:30
# batch_num:31
# batch_num:32
# batch_num:33
# batch_num:34
# batch_num:35
# batch_num:36
# batch_num:37
# batch_num:38
# batch_num:39
# batch_num:40
# batch_num:41
# batch_num:42
# batch_num:43
# batch_num:44
# batch_num:45
# batch_num:46
# batch_num:47
# batch_num:48
# batch_num:49
# batch_num:50
# batch_num:51
# batch_num:52
# batch_num:53
# batch_num:54
# batch_num:55
# batch_num:56
# batch_num:57
# batch_num:58
# batch_num:59
# batch_num:60
# batch_num:61
# batch_num:62
# batch_num:63
# batch_num:64
# batch_num:65
# batch_num:66
# batch_num:67
# batch_num:68
# batch_num:69
# batch_num:70
# batch_num:71
# batch_num:72
# batch_num:73
# batch_num:74
# batch_num:75
# batch_num:76
# batch_num:77
# batch_num:78
# batch_num:79
# batch_num:80
# batch_num:81
# batch_num:82
# batch_num:83
# batch_num:84
# batch_num:85
# batch_num:86
# batch_num:87
# batch_num:88
# batch_num:89
# batch_num:90
# batch_num:91
# batch_num:92
# batch_num:93
# batch_num:94
# batch_num:95
# batch_num:96
# batch_num:97
# batch_num:98
# batch_num:99
# batch_num:100
# batch_num:101
# batch_num:102
# batch_num:103
# batch_num:104
# batch_num:105
# batch_num:106
# batch_num:107
# batch_num:108
# batch_num:109
# batch_num:110
# batch_num:111
# batch_num:112
# batch_num:113
# batch_num:114
# batch_num:115
# batch_num:116
# batch_num:117
# batch_num:118
# batch_num:119
# batch_num:120
# batch_num:121
# batch_num:122
# batch_num:123
# batch_num:124
# batch_num:125
# batch_num:126
# batch_num:127
# batch_num:128
# batch_num:129
# batch_num:130
# batch_num:131
# batch_num:132
# batch_num:133
# batch_num:134
# batch_num:135
# batch_num:136
# batch_num:137
# batch_num:138
# batch_num:139
# batch_num:140
# batch_num:141
# batch_num:142
# batch_num:143
# batch_num:144
# batch_num:145
# batch_num:146
# batch_num:147
# batch_num:148
# batch_num:149
# batch_num:150
# batch_num:151
# batch_num:152
# batch_num:153
# batch_num:154
# batch_num:155
# batch_num:156
# batch_num:157
# batch_num:158
# batch_num:159
# batch_num:160
# batch_num:161
# batch_num:162
# batch_num:163
# batch_num:164
# batch_num:165
# batch_num:166
# batch_num:167
# batch_num:168
# batch_num:169
# batch_num:170
# batch_num:171
# batch_num:172
# batch_num:173
# batch_num:174
# batch_num:175
# batch_num:176
# batch_num:177
# batch_num:178
# batch_num:179
# batch_num:180
# batch_num:181
# batch_num:182
# batch_num:183
# batch_num:184
# batch_num:185
# batch_num:186
# batch_num:187
# batch_num:188
# batch_num:189
# batch_num:190
# batch_num:191
# batch_num:192
# batch_num:193
# batch_num:194
# batch_num:195
# batch_num:196
# batch_num:197
# batch_num:198
# batch_num:199
# batch_num:200
# batch_num:201
# batch_num:202
# batch_num:203
# batch_num:204
# batch_num:205
# batch_num:206
# batch_num:207
# batch_num:208
# batch_num:209
# batch_num:210
# batch_num:211
# batch_num:212
# batch_num:213
# batch_num:214
# batch_num:215
# batch_num:216
# batch_num:217
# batch_num:218
# batch_num:219
# batch_num:220
# batch_num:221
# batch_num:222
# batch_num:223
# batch_num:224
# batch_num:225
# batch_num:226
# batch_num:227
# batch_num:228
# batch_num:229
# batch_num:230
# batch_num:231
# batch_num:232
# batch_num:233
# batch_num:234
# batch_num:235
# batch_num:236
# batch_num:237
# batch_num:238
# batch_num:239
# batch_num:240
# batch_num:241
# batch_num:242
# batch_num:243
# batch_num:244
# batch_num:245
# batch_num:246
# batch_num:247
# batch_num:248
# batch_num:249
# batch_num:250
# batch_num:251
# batch_num:252
# batch_num:253
# batch_num:254
# batch_num:255
# batch_num:256
# batch_num:257
# batch_num:258
# batch_num:259
# batch_num:260
# batch_num:261
# batch_num:262
# batch_num:263
# batch_num:264
# batch_num:265
# batch_num:266
# batch_num:267
# batch_num:268
# batch_num:269
# batch_num:270
# batch_num:271
# batch_num:272
# batch_num:273
# batch_num:274
# batch_num:275
# batch_num:276
# batch_num:277
# batch_num:278
# batch_num:279
# batch_num:280
# batch_num:281
# batch_num:282
# batch_num:283
# batch_num:284
# batch_num:285
# batch_num:286
# batch_num:287
# batch_num:288
# batch_num:289
# batch_num:290
# batch_num:291
# batch_num:292
# batch_num:293
# batch_num:294
# batch_num:295
# batch_num:296
# batch_num:297
# batch_num:298
# batch_num:299
# batch_num:300
# batch_num:301
# batch_num:302
# batch_num:303
# batch_num:304
# batch_num:305
# batch_num:306
# batch_num:307
# batch_num:308
# batch_num:309
# batch_num:310
# batch_num:311
# batch_num:312
# batch_num:313
# batch_num:314
# batch_num:315
# batch_num:316
# batch_num:317
# batch_num:318
# batch_num:319
# batch_num:320
# batch_num:321
# batch_num:322
# batch_num:323
# batch_num:324
# batch_num:325
# batch_num:326
# batch_num:327
# batch_num:328
# batch_num:329
# batch_num:330
# batch_num:331
# batch_num:332
# batch_num:333
# batch_num:334
# batch_num:335
# batch_num:336
# batch_num:337
# batch_num:338
# batch_num:339
# batch_num:340
# batch_num:341
# batch_num:342
# batch_num:343
# batch_num:344
# batch_num:345
# batch_num:346
# batch_num:347
# batch_num:348
# batch_num:349
# batch_num:350
# batch_num:351
# batch_num:352
# batch_num:353
# batch_num:354
# batch_num:355
# batch_num:356
# batch_num:357
# batch_num:358
# batch_num:359
# batch_num:360
# batch_num:361
# batch_num:362
# batch_num:363
# batch_num:364
# batch_num:365
# batch_num:366
# batch_num:367
# batch_num:368
# batch_num:369
# batch_num:370
# batch_num:371
# batch_num:372
# batch_num:373
# batch_num:374
# batch_num:375
# batch_num:376
# batch_num:377
# batch_num:378
# batch_num:379
# batch_num:380
# batch_num:381
# batch_num:382
# batch_num:383
# batch_num:384
# batch_num:385
# batch_num:386
# batch_num:387
# batch_num:388
# batch_num:389
# batch_num:390
# batch_num:391
# batch_num:392
# batch_num:393
# batch_num:394
# batch_num:395
# batch_num:396
# batch_num:397
# batch_num:398
# batch_num:399
# batch_num:400
# batch_num:401
# batch_num:402
# batch_num:403
# batch_num:404
# batch_num:405
# batch_num:406
# batch_num:407
# batch_num:408
# batch_num:409
# batch_num:410
# batch_num:411
# batch_num:412
# batch_num:413
# batch_num:414
# batch_num:415
# batch_num:416
# batch_num:417
# batch_num:418
# batch_num:419
# batch_num:420
# batch_num:421
# batch_num:422
# batch_num:423
# batch_num:424
# batch_num:425
# batch_num:426
# batch_num:427
# batch_num:428
# batch_num:429
# batch_num:430
# batch_num:431
# batch_num:432
# batch_num:433
# batch_num:434
# batch_num:435
# batch_num:436
# batch_num:437
# batch_num:438
# batch_num:439
# batch_num:440
# batch_num:441
# batch_num:442
# batch_num:443
# batch_num:444
# batch_num:445
# batch_num:446
# batch_num:447
# batch_num:448
# batch_num:449
# batch_num:450
# batch_num:451
# batch_num:452
# batch_num:453
# batch_num:454
# batch_num:455
# batch_num:456
# batch_num:457
# batch_num:458
# batch_num:459
# batch_num:460
# batch_num:461
# batch_num:462
# batch_num:463
# batch_num:464
# batch_num:465
# batch_num:466
# batch_num:467
# batch_num:468
# batch_num:469
# batch_num:470
# batch_num:471
# batch_num:472
# batch_num:473
# batch_num:474
# batch_num:475
# batch_num:476
# batch_num:477
# batch_num:478
# batch_num:479
# batch_num:480
# batch_num:481
# batch_num:482
# batch_num:483
# batch_num:484
# batch_num:485
# batch_num:486
# batch_num:487
# batch_num:488
# batch_num:489
# batch_num:490
# batch_num:491
# batch_num:492
# batch_num:493
# batch_num:494
# batch_num:495
# batch_num:496
# batch_num:497
# batch_num:498
# batch_num:499
# batch_num:500
# batch_num:501
# batch_num:502
# batch_num:503
# batch_num:504
# batch_num:505
# batch_num:506
# batch_num:507
# batch_num:508
# batch_num:509
# batch_num:510
# batch_num:511
# batch_num:512
# batch_num:513
# batch_num:514
# batch_num:515
# batch_num:516
# batch_num:517
# batch_num:518
# batch_num:519
# batch_num:520
# batch_num:521
# batch_num:522
# batch_num:523
# batch_num:524
# batch_num:525
# batch_num:526
# batch_num:527
# batch_num:528
# batch_num:529
# batch_num:530
# batch_num:531
# batch_num:532
# batch_num:533
# batch_num:534
# batch_num:535
# batch_num:536
# batch_num:537
# batch_num:538
# batch_num:539
# batch_num:540
# batch_num:541
# batch_num:542
# batch_num:543
# batch_num:544
# batch_num:545
# batch_num:546
# batch_num:547
# batch_num:548
# batch_num:549
# batch_num:550
# batch_num:551
# batch_num:552
# batch_num:553
# batch_num:554
# batch_num:555
# batch_num:556
# batch_num:557
# batch_num:558
# batch_num:559
# batch_num:560
# batch_num:561
# batch_num:562
# batch_num:563
# batch_num:564
# batch_num:565
# batch_num:566
# batch_num:567
# batch_num:568
# batch_num:569
# batch_num:570
# batch_num:571
# batch_num:572
# batch_num:573
# batch_num:574
# batch_num:575
# batch_num:576
# batch_num:577
# batch_num:578
# batch_num:579
# batch_num:580
# batch_num:581
# batch_num:582
# batch_num:583
# batch_num:584
# batch_num:585
# batch_num:586
# batch_num:587
# batch_num:588
# batch_num:589
# batch_num:590
# batch_num:591
# batch_num:592
# batch_num:593
# batch_num:594
# batch_num:595
# batch_num:596
# batch_num:597
# batch_num:598
# batch_num:599
# batch_num:600
# batch_num:601
# batch_num:602
# batch_num:603
# batch_num:604
# batch_num:605
# batch_num:606
# batch_num:607
# batch_num:608
# batch_num:609
# batch_num:610
# batch_num:611
# batch_num:612
# batch_num:613
# batch_num:614
# batch_num:615
# batch_num:616
# batch_num:617
# batch_num:618
# batch_num:619
# batch_num:620
# batch_num:621
# batch_num:622
# batch_num:623
# batch_num:624
# batch_num:625
# batch_num:626
# batch_num:627
# batch_num:628
# batch_num:629
# batch_num:630
# batch_num:631
# batch_num:632
# batch_num:633
# batch_num:634
# batch_num:635
# batch_num:636
# batch_num:637
# batch_num:638
# batch_num:639
# batch_num:640
# batch_num:641
# batch_num:642
# batch_num:643
# batch_num:644
# batch_num:645
# batch_num:646
# batch_num:647
# batch_num:648
# batch_num:649
# batch_num:650
# batch_num:651
# batch_num:652
# batch_num:653
# batch_num:654
# batch_num:655
# batch_num:656
# batch_num:657
# batch_num:658
# batch_num:659
# batch_num:660
# batch_num:661
# batch_num:662
# batch_num:663
# batch_num:664
# batch_num:665
# batch_num:666
# batch_num:667
# batch_num:668
# batch_num:669
# batch_num:670
# batch_num:671
# batch_num:672
# batch_num:673
# batch_num:674
# batch_num:675
# batch_num:676
# batch_num:677
# batch_num:678
# batch_num:679
# batch_num:680
# batch_num:681
# batch_num:682
# batch_num:683
# batch_num:684
# batch_num:685
# batch_num:686
# batch_num:687
# batch_num:688
# batch_num:689
# batch_num:690
# batch_num:691
# batch_num:692
# batch_num:693
# batch_num:694
# batch_num:695
# batch_num:696
# batch_num:697
# batch_num:698
# batch_num:699
# batch_num:700
# batch_num:701
# batch_num:702
# batch_num:703
# batch_num:704
# batch_num:705
# batch_num:706
# batch_num:707
# batch_num:708
# batch_num:709
# batch_num:710
# batch_num:711
# batch_num:712
# batch_num:713
# batch_num:714
# batch_num:715
# batch_num:716
# batch_num:717
# batch_num:718
# batch_num:719
# batch_num:720
# batch_num:721
# batch_num:722
# batch_num:723
# batch_num:724
# batch_num:725
# batch_num:726
# batch_num:727
# batch_num:728
# batch_num:729
# batch_num:730
# batch_num:731
# batch_num:732
# batch_num:733
# batch_num:734
# batch_num:735
# batch_num:736
# batch_num:737
# batch_num:738
# batch_num:739
# batch_num:740
# batch_num:741
# batch_num:742
# batch_num:743
# batch_num:744
# batch_num:745
# batch_num:746
# batch_num:747
# batch_num:748
# batch_num:749
# batch_num:750
# batch_num:751
# batch_num:752
# batch_num:753
# batch_num:754
# batch_num:755
# batch_num:756
# batch_num:757
# batch_num:758
# batch_num:759
# batch_num:760
# batch_num:761
# batch_num:762
# batch_num:763
# batch_num:764
# batch_num:765
# batch_num:766
# batch_num:767
# batch_num:768
# batch_num:769
# batch_num:770
# batch_num:771
# batch_num:772
# batch_num:773
# batch_num:774
# batch_num:775
# batch_num:776
# batch_num:777
# batch_num:778
# batch_num:779
# batch_num:780
# batch_num:781
# batch_num:782
# batch_num:783
# batch_num:784
# batch_num:785
# batch_num:786
# batch_num:787
# batch_num:788
# batch_num:789
# batch_num:790
# batch_num:791
# batch_num:792
# batch_num:793
# batch_num:794
# batch_num:795
# batch_num:796
# batch_num:797
# batch_num:798
# batch_num:799
# batch_num:800
# batch_num:801
# batch_num:802
# batch_num:803
# batch_num:804
# batch_num:805
# batch_num:806
# batch_num:807
# batch_num:808
# batch_num:809
# batch_num:810
# batch_num:811
# batch_num:812
# batch_num:813
# batch_num:814
# batch_num:815
# batch_num:816
# batch_num:817
# batch_num:818
# batch_num:819
# batch_num:820
# batch_num:821
# batch_num:822
# batch_num:823
# batch_num:824
# batch_num:825
# batch_num:826
# batch_num:827
# batch_num:828
# batch_num:829
# batch_num:830
# batch_num:831
# batch_num:832
# batch_num:833
# batch_num:834
# batch_num:835
# batch_num:836
# batch_num:837
# batch_num:838
# batch_num:839
# batch_num:840
# batch_num:841
# batch_num:842
# batch_num:843
# batch_num:844
# batch_num:845
# batch_num:846
# batch_num:847
# batch_num:848
# batch_num:849
# batch_num:850
# batch_num:851
# batch_num:852
# batch_num:853
# batch_num:854
# batch_num:855
# batch_num:856
# batch_num:857
# batch_num:858
# batch_num:859
# batch_num:860
# batch_num:861
# batch_num:862
# batch_num:863
# batch_num:864
# batch_num:865
# batch_num:866
# batch_num:867
# batch_num:868
# batch_num:869
# batch_num:870
# batch_num:871
# batch_num:872
# batch_num:873
# batch_num:874
# batch_num:875
# batch_num:876
# batch_num:877
# batch_num:878
# batch_num:879
# batch_num:880
# batch_num:881
# batch_num:882
# batch_num:883
# batch_num:884
# batch_num:885
# batch_num:886
# batch_num:887
# batch_num:888
# batch_num:889
# batch_num:890
# batch_num:891
# batch_num:892
# batch_num:893
# batch_num:894
# batch_num:895
# batch_num:896
# batch_num:897
# batch_num:898
# batch_num:899
# batch_num:900
# batch_num:901
# batch_num:902
# batch_num:903
# batch_num:904
# batch_num:905
# batch_num:906
# batch_num:907
# batch_num:908
# batch_num:909
# batch_num:910
# batch_num:911
# batch_num:912
# batch_num:913
# batch_num:914
# batch_num:915
# batch_num:916
# batch_num:917
# batch_num:918
# batch_num:919
# batch_num:920
# batch_num:921
# batch_num:922
# batch_num:923
# batch_num:924
# batch_num:925
# batch_num:926
# batch_num:927
# batch_num:928
# batch_num:929
# batch_num:930
# batch_num:931
# batch_num:932
# batch_num:933
# batch_num:934
# batch_num:935
# batch_num:936
# batch_num:937
# batch_num:938
# batch_num:939
# batch_num:940
# batch_num:941
# batch_num:942
# batch_num:943
# batch_num:944
# batch_num:945
# batch_num:946
# batch_num:947
# batch_num:948
# batch_num:949
# batch_num:950
# batch_num:951
# batch_num:952
# batch_num:953
# batch_num:954
# batch_num:955
# batch_num:956
# batch_num:957
# batch_num:958
# batch_num:959
# batch_num:960
# batch_num:961
# batch_num:962
# batch_num:963
# batch_num:964
# batch_num:965
# batch_num:966
# batch_num:967
# batch_num:968
# batch_num:969
# batch_num:970
# batch_num:971
# batch_num:972
# batch_num:973
# batch_num:974
# batch_num:975
# batch_num:976
# batch_num:977
# batch_num:978
# batch_num:979
# batch_num:980
# batch_num:981
# batch_num:982
# batch_num:983
# batch_num:984
# batch_num:985
# batch_num:986
# batch_num:987
# batch_num:988
# batch_num:989
# batch_num:990
# batch_num:991
# batch_num:992
# batch_num:993
# batch_num:994
# batch_num:995
# batch_num:996
# batch_num:997
# batch_num:998
# batch_num:999
# batch_num:1000
# batch_num:1001
# batch_num:1002
# batch_num:1003
# batch_num:1004
# batch_num:1005
# batch_num:1006
# batch_num:1007
# batch_num:1008
# batch_num:1009
# batch_num:1010
# batch_num:1011
# batch_num:1012
# batch_num:1013
# batch_num:1014
# batch_num:1015
# batch_num:1016
# batch_num:1017
# batch_num:1018
# batch_num:1019
# batch_num:1020
# batch_num:1021
# batch_num:1022
# batch_num:1023
# batch_num:1024
# batch_num:1025
# batch_num:1026
# batch_num:1027
# batch_num:1028
# batch_num:1029
# batch_num:1030
# batch_num:1031
# batch_num:1032
# batch_num:1033
# batch_num:1034
# batch_num:1035
# batch_num:1036
# batch_num:1037
# batch_num:1038
# batch_num:1039
# batch_num:1040
# batch_num:1041
# batch_num:1042
# batch_num:1043
# batch_num:1044
# batch_num:1045
# batch_num:1046
# batch_num:1047
# batch_num:1048
# batch_num:1049
# batch_num:1050
# batch_num:1051
# batch_num:1052
# batch_num:1053
# batch_num:1054
# batch_num:1055
# batch_num:1056
# batch_num:1057
# batch_num:1058
# batch_num:1059
# batch_num:1060
# batch_num:1061
# batch_num:1062
# batch_num:1063
# batch_num:1064
# batch_num:1065
# batch_num:1066
# batch_num:1067
# batch_num:1068
# batch_num:1069
# batch_num:1070
# batch_num:1071
# batch_num:1072
# batch_num:1073
# batch_num:1074
# batch_num:1075
# batch_num:1076
# batch_num:1077
# batch_num:1078
# batch_num:1079
# batch_num:1080
# batch_num:1081
# batch_num:1082
# batch_num:1083
# batch_num:1084
# batch_num:1085
# batch_num:1086
# batch_num:1087
# batch_num:1088
# batch_num:1089
# batch_num:1090
# batch_num:1091
# batch_num:1092
# batch_num:1093
# batch_num:1094
# batch_num:1095
# batch_num:1096
# batch_num:1097
# batch_num:1098
# batch_num:1099
# batch_num:1100
# batch_num:1101
# batch_num:1102
# batch_num:1103
# batch_num:1104
# batch_num:1105
# batch_num:1106
# batch_num:1107
# batch_num:1108
# batch_num:1109
# batch_num:1110
# batch_num:1111
# batch_num:1112
# batch_num:1113
# batch_num:1114
# batch_num:1115
# batch_num:1116
# batch_num:1117
# batch_num:1118
# batch_num:1119
# batch_num:1120
# batch_num:1121
# batch_num:1122
# batch_num:1123
# batch_num:1124
# batch_num:1125
# batch_num:1126
# batch_num:1127
# batch_num:1128
# batch_num:1129
# batch_num:1130
# batch_num:1131
# batch_num:1132
# batch_num:1133
# batch_num:1134
# batch_num:1135
# batch_num:1136
# batch_num:1137
# batch_num:1138
# batch_num:1139
# batch_num:1140
# batch_num:1141
# batch_num:1142
# batch_num:1143
# batch_num:1144
# batch_num:1145
# batch_num:1146
# batch_num:1147
# batch_num:1148
# batch_num:1149
# batch_num:1150
# batch_num:1151
# batch_num:1152
# batch_num:1153
# batch_num:1154
# batch_num:1155
# batch_num:1156
# batch_num:1157
# batch_num:1158
# batch_num:1159
# batch_num:1160
# batch_num:1161
# batch_num:1162
# batch_num:1163
# batch_num:1164
# batch_num:1165
# batch_num:1166
# batch_num:1167
# batch_num:1168
# batch_num:1169
# batch_num:1170
# batch_num:1171
# batch_num:1172
# batch_num:1173
# batch_num:1174
# batch_num:1175
# batch_num:1176
# batch_num:1177
# batch_num:1178
# batch_num:1179
# batch_num:1180
# batch_num:1181
# batch_num:1182
# batch_num:1183
# batch_num:1184
# batch_num:1185
# batch_num:1186
# batch_num:1187
# batch_num:1188
# batch_num:1189
# batch_num:1190
# batch_num:1191
# batch_num:1192
# batch_num:1193
# batch_num:1194
# batch_num:1195
# batch_num:1196
# batch_num:1197
# batch_num:1198
# batch_num:1199
# batch_num:1200
# batch_num:1201
# batch_num:1202
# batch_num:1203
# batch_num:1204
# batch_num:1205
# batch_num:1206
# batch_num:1207
# batch_num:1208
# batch_num:1209
# batch_num:1210
# batch_num:1211
# batch_num:1212
# batch_num:1213
# batch_num:1214
# batch_num:1215
# batch_num:1216
# batch_num:1217
# batch_num:1218
# batch_num:1219
# batch_num:1220
# batch_num:1221
# batch_num:1222
# batch_num:1223
# batch_num:1224
# batch_num:1225
# batch_num:1226
# batch_num:1227
# batch_num:1228
# batch_num:1229
# batch_num:1230
# batch_num:1231
# batch_num:1232
# batch_num:1233
# batch_num:1234
# batch_num:1235
# batch_num:1236
# batch_num:1237
# batch_num:1238
# batch_num:1239
# batch_num:1240
# batch_num:1241
# batch_num:1242
# batch_num:1243
# batch_num:1244
# batch_num:1245
# batch_num:1246
# batch_num:1247
# batch_num:1248
# batch_num:1249
# batch_num:1250
# batch_num:1251
# batch_num:1252
# batch_num:1253
# batch_num:1254
# batch_num:1255
# batch_num:1256
# batch_num:1257
# batch_num:1258
# batch_num:1259
# batch_num:1260
# batch_num:1261
# batch_num:1262
# batch_num:1263
# batch_num:1264
# batch_num:1265
# batch_num:1266
# batch_num:1267
# batch_num:1268
# batch_num:1269
# batch_num:1270
# batch_num:1271
# batch_num:1272
# batch_num:1273
# batch_num:1274
# batch_num:1275
# batch_num:1276
# batch_num:1277
# batch_num:1278
# batch_num:1279
# batch_num:1280
# batch_num:1281
# batch_num:1282
# batch_num:1283
# batch_num:1284
# batch_num:1285
# batch_num:1286
# batch_num:1287
# batch_num:1288
# batch_num:1289
# batch_num:1290
# batch_num:1291
# batch_num:1292
# batch_num:1293
# batch_num:1294
# batch_num:1295
# batch_num:1296
# batch_num:1297
# batch_num:1298
# batch_num:1299
# batch_num:1300
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 results = train(model,train_dataloader,test_dataloader,5,optimizer,loss_fn,accuracy_fn,device)
#
# Cell In[22], line 20, in train(model, train_dataloader, test_dataloader, epochs, optimizer, loss_fn, accuracy_fn, device)
#      18 start = timer()
#      19 for epoch in tqdm(range(epochs)):
# ---> 20     train_loss,train_acc = train_step(model,optimizer,loss_fn,train_dataloader,accuracy_fn,device)
#      21     test_loss,test_acc = test_step(model,test_dataloader,loss_fn,accuracy_fn,device)
#      22     print(f"Epochs :{epoch} | Train loss :{train_loss:.4} | Train accuracy :{train_acc:.3} | Test loss :{test_loss:.4} | Test accuracy :{test_acc:.3} " )
#
# Cell In[20], line 18, in train_step(model, optimizer, loss_fn, dataloader, accuracy_fn, device)
#      15     train_loss+=loss.item()
#      17     optimizer.zero_grad()
# ---> 18     loss.backward()
#      19     optimizer.step()
#      20 train_acc/=len(dataloader)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\_tensor.py:647, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     637 if has_torch_function_unary(self):
#     638     return handle_torch_function(
#     639         Tensor.backward,
#     640         (self,),
#    (...)    645         inputs=inputs,
#     646     )
# --> 647 torch.autograd.backward(
#     648     self, gradient, retain_graph, create_graph, inputs=inputs
#     649 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\autograd\__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\autograd\graph.py:829, in _engine_run_backward(t_outputs, *args, **kwargs)
#     827     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828 try:
# --> 829     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830         t_outputs, *args, **kwargs
#     831     )  # Calls into the C++ engine to run the backward pass
#     832 finally:
#     833     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
#let's predict on my custome image
import requests
from pathlib import Path
data_path=Path('image_data/')
if data_path.is_dir():
  print('your picture is already exist')
else:

  source="https://hips.hearstapps.com/hmg-prod/amv-prod-cad-assets/images/09q4/300860/2012-lexus-lfa-review-car-and-driver-photo-302743-s-original.jpg"
  target_file = Path(source).name
  data_path.mkdir(parents=True, exist_ok=True)
  with open(data_path / target_file , "wb") as f:
        request = requests.get(source)
        print(f"Downloading {target_file} from {source}")
        f.write(request.content)
# Out:
# your picture is already exist

# %%
from PIL import Image

img_path = Path("image_data/").glob('*.jpg')
img_path = list(img_path)[0]


img = Image.open(img_path).convert('RGB') # Convert to RGB to ensure 3 channels

transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize((128,128)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(mean,std)
])

img_transformed = transform(img)
img_show = img_transformed *std[:,None,None] + mean[:,None,None]
plt.imshow(img_show.permute(1,2,0))

model.eval()
with torch.inference_mode():
    pred_logits = model(img_transformed.unsqueeze(0))
    pred_num = pred_logits.argmax(dim=1).item()
print(f'Our prediction is {class_names[pred_num]} wait this chance {pred_logits.max() : 0.3}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       4 img_path = list(img_path)[0]
#       7 img = Image.open(img_path).convert('RGB') # Convert to RGB to ensure 3 channels
# ----> 9 transform = torchvision.transforms.Compose([
#      10     torchvision.transforms.Resize((128,128)),
#      11     torchvision.transforms.ToTensor(),
#      12     torchvision.transforms.Normalize(mean,std)
#      13 ])
#      15 img_transformed = transform(img)
#      16 img_show = img_transformed *std[:,None,None] + mean[:,None,None]
#
# NameError: name 'torchvision' is not defined
